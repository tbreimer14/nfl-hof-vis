# %%
import pandas as pd
import time

col_names = ['Name', 'G','GS', 'QBrec', 'Cmp','Att','Cmp%','Yds','TD','TD%','Int','Int%','1D','Succ%','Lng','Y/A','AY/A','Y/C','Y/G','Rate','Sk','Yds.1','Sk%','NY/A','ANY/A','4QC','GWD','AV','HOF']
stat_df = pd.DataFrame(columns=col_names)

# Load passing_leaders_filtered.csv into a DataFrame
passing_leaders_df = pd.read_csv('passing_leaders_filtered.csv')

alt_number = {"Joe Montana": "01", "Alex Smith": "03", "Danny White": "01"}

# issues: Steve Deberg

starting_name = "John Brodie"
start = True

for leader_row in passing_leaders_df.itertuples():
    # Create the URL for the player's PFR page
    player = leader_row.Player

    if player == starting_name:
        start = True

    if not start:
        continue
    
    # Split player name into first and last name
    first_name, last_name = player.split(" ", 1)
    last_name = last_name.replace(" ", "").replace("'", "")

    # Deal with players who have alt url
    if player in alt_number:
        url = f'https://www.pro-football-reference.com/players/{last_name[0]}/{last_name[:4]}{first_name[0:2]}{alt_number[player]}.htm'
    else:
        url = f'https://www.pro-football-reference.com/players/{last_name[0]}/{last_name[:4]}{first_name[0:2]}00.htm'

    print(url)

    # Use pandas to read HTML tables from the URL. It returns a list of DataFrames.
    try:
        df = pd.read_html(url)[0]
        # Find row in DataFrame where "Season" column contains "Yrs" in string, the first will be the career totals
        
        row = df[df['Season'].astype(str).str.contains('Yrs', na=False)].iloc[0]
        row["HOF"] = leader_row.HOF
        row["Name"] = leader_row.Player


        # Placeholder value for missing entries in the new row
        placeholder_value = None

        reindexed_series = row.reindex(stat_df.columns, fill_value=placeholder_value)
        row = reindexed_series.to_frame().T

        # Concatenate the original DataFrame and the new row DataFrame
        # Use ignore_index=True to reset the index of the resulting DataFrame
        stat_df = pd.concat([stat_df, row], ignore_index=True)

        print(f"Retrieved data for {player}\n")

    except Exception as e:
        print(f"Could not retrieve data for {player}: {e}\n")

    # May not exceed 10 requests per minute
    time.sleep(15)

    # save stat_df to csv
    stat_df.to_csv('career_stats.csv', index=False)
# Out:
# https://www.pro-football-reference.com/players/B/BreeDr00.htm
# Retrieved data for Drew Brees
#
# https://www.pro-football-reference.com/players/M/MannPe00.htm
# Retrieved data for Peyton Manning
#
# https://www.pro-football-reference.com/players/F/FavrBr00.htm
# Retrieved data for Brett Favre
#
# https://www.pro-football-reference.com/players/M/MariDa00.htm
# Retrieved data for Dan Marino
#
# https://www.pro-football-reference.com/players/M/MannEl00.htm
# Retrieved data for Eli Manning
#
# https://www.pro-football-reference.com/players/E/ElwaJo00.htm
# Retrieved data for John Elway
#
# https://www.pro-football-reference.com/players/M/MoonWa00.htm
# Retrieved data for Warren Moon
#
# https://www.pro-football-reference.com/players/T/TarkFr00.htm
# Retrieved data for Fran Tarkenton
#
# https://www.pro-football-reference.com/players/P/PalmCa00.htm
# Retrieved data for Carson Palmer
#
# https://www.pro-football-reference.com/players/T/TestVi00.htm
# Retrieved data for Vinny Testaverde
#
# https://www.pro-football-reference.com/players/B/BledDr00.htm
# Retrieved data for Drew Bledsoe
#
# https://www.pro-football-reference.com/players/F/FoutDa00.htm
# Retrieved data for Dan Fouts
#
# https://www.pro-football-reference.com/players/C/CollKe00.htm
# Retrieved data for Kerry Collins
#
# https://www.pro-football-reference.com/players/M/MontJo01.htm
# Retrieved data for Joe Montana
#
# https://www.pro-football-reference.com/players/U/UnitJo00.htm
# Retrieved data for Johnny Unitas
#
# https://www.pro-football-reference.com/players/K/KrieDa00.htm
# Retrieved data for Dave Krieg
#
# https://www.pro-football-reference.com/players/E/EsiaBo00.htm
# Retrieved data for Boomer Esiason
#
# https://www.pro-football-reference.com/players/M/McNaDo00.htm
# Retrieved data for Donovan McNabb
#
# https://www.pro-football-reference.com/players/H/HassMa00.htm
# Retrieved data for Matt Hasselbeck
#
# https://www.pro-football-reference.com/players/S/SmitAl03.htm
# Retrieved data for Alex Smith
#
# https://www.pro-football-reference.com/players/K/KellJi00.htm
# Retrieved data for Jim Kelly
#
# https://www.pro-football-reference.com/players/C/CutlJa00.htm
# Retrieved data for Jay Cutler
#
# https://www.pro-football-reference.com/players/E/EverJi00.htm
# Retrieved data for Jim Everett
#
# https://www.pro-football-reference.com/players/H/HartJi00.htm
# Retrieved data for Jim Hart
#
# https://www.pro-football-reference.com/players/D/DeBeSt00.htm
# Could not retrieve data for Steve DeBerg: HTTP Error 404: Not Found
#
# https://www.pro-football-reference.com/players/R/RomoTo00.htm
# Retrieved data for Tony Romo
#
# https://www.pro-football-reference.com/players/H/HadlJo00.htm
# Retrieved data for John Hadl
#
# https://www.pro-football-reference.com/players/S/SimmPh00.htm
# Retrieved data for Phil Simms
#
# https://www.pro-football-reference.com/players/Y/YounSt00.htm
# Retrieved data for Steve Young
#
# https://www.pro-football-reference.com/players/T/TittY.00.htm
# Retrieved data for Y.A. Tittle
#
# https://www.pro-football-reference.com/players/A/AikmTr00.htm
# Retrieved data for Troy Aikman
#
# https://www.pro-football-reference.com/players/A/AndeKe00.htm
# Retrieved data for Ken Anderson
#
# https://www.pro-football-reference.com/players/W/WarnKu00.htm
# Retrieved data for Kurt Warner
#
# https://www.pro-football-reference.com/players/J/JurgSo00.htm
# Retrieved data for Sonny Jurgensen
#
# https://www.pro-football-reference.com/players/B/BrunMa00.htm
# Retrieved data for Mark Brunell
#
# https://www.pro-football-reference.com/players/B/BrodJo00.htm
# Retrieved data for John Brodie
#
# https://www.pro-football-reference.com/players/M/McNaSt00.htm
# Retrieved data for Steve McNair
#
# https://www.pro-football-reference.com/players/S/SneaNo00.htm
# Retrieved data for Norm Snead
#
# https://www.pro-football-reference.com/players/C/CunnRa00.htm
# Retrieved data for Randall Cunningham
#
# https://www.pro-football-reference.com/players/F/FergJo00.htm
# Retrieved data for Joe Ferguson
#
# https://www.pro-football-reference.com/players/K/KitnJo00.htm
# Retrieved data for Jon Kitna
#
# https://www.pro-football-reference.com/players/G/GabrRo00.htm
# Retrieved data for Roman Gabriel
#
# https://www.pro-football-reference.com/players/P/PlumJa00.htm
# Retrieved data for Jake Plummer
#
# https://www.pro-football-reference.com/players/J/JohnBr00.htm
# Retrieved data for Brad Johnson
#
# https://www.pro-football-reference.com/players/G/GannRi00.htm
# Retrieved data for Rich Gannon
#
# https://www.pro-football-reference.com/players/D/DawsLe00.htm
# Retrieved data for Len Dawson
#
# https://www.pro-football-reference.com/players/C/ChanCh00.htm
# Retrieved data for Chris Chandler
#
# https://www.pro-football-reference.com/players/G/GreeTr00.htm
# Retrieved data for Trent Green
#
# https://www.pro-football-reference.com/players/J/JawoRo00.htm
# Retrieved data for Ron Jaworski
#
# https://www.pro-football-reference.com/players/B/BradTe00.htm
# Retrieved data for Terry Bradshaw
#
# https://www.pro-football-reference.com/players/S/StabKe00.htm
# Retrieved data for Ken Stabler
#
# https://www.pro-football-reference.com/players/M/MortCr00.htm
# Retrieved data for Craig Morton
#
# https://www.pro-football-reference.com/players/N/NamaJo00.htm
# Retrieved data for Joe Namath
#
# https://www.pro-football-reference.com/players/G/GeorJe00.htm
# Retrieved data for Jeff George
#
# https://www.pro-football-reference.com/players/B/BlanGe00.htm
# Retrieved data for George Blanda
#
# https://www.pro-football-reference.com/players/G/GrogSt00.htm
# Retrieved data for Steve Grogan
#
# https://www.pro-football-reference.com/players/L/LaynBo00.htm
# Retrieved data for Bobby Layne
#
# https://www.pro-football-reference.com/players/H/HarbJi00.htm
# Retrieved data for Jim Harbaugh
#
# https://www.pro-football-reference.com/players/P/PlunJi00.htm
# Retrieved data for Jim Plunkett
#
# https://www.pro-football-reference.com/players/G/GarcJe00.htm
# Retrieved data for Jeff Garcia
#
# https://www.pro-football-reference.com/players/S/SchaMa00.htm
# Retrieved data for Matt Schaub
#
# https://www.pro-football-reference.com/players/T/TheiJo00.htm
# Retrieved data for Joe Theismann
#
# https://www.pro-football-reference.com/players/O/OBriKe00.htm
# Retrieved data for Ken O'Brien
#
# https://www.pro-football-reference.com/players/G/GrieBo00.htm
# Retrieved data for Bob Griese
#
# https://www.pro-football-reference.com/players/K/KramTo00.htm
# Retrieved data for Tommy Kramer
#
# https://www.pro-football-reference.com/players/S/StarBa00.htm
# Retrieved data for Bart Starr
#
# https://www.pro-football-reference.com/players/J/JohnCh00.htm
# Could not retrieve data for Charley Johnson: 'Season'
#
# https://www.pro-football-reference.com/players/C/CulpDa00.htm
# Retrieved data for Daunte Culpepper
#
# https://www.pro-football-reference.com/players/B/BartSt00.htm
# Retrieved data for Steve Bartkowski
